# %% [markdown]
# <a href="https://colab.research.google.com/github/suparna-kouri/portfolio-template/blob/main/ASSIGNMENT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LSTM

# %%
from tensorflow.keras.layers import Embedding,LSTM,Dense
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(LSTM(128))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
epochs = 5
batch_size = 128

hist=model.fit(xt, yt, epochs=epochs, batch_size=batch_size)
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# Epoch 1/5
# 196/196 [==============================] - 37s 179ms/step - loss: 0.4840 - accuracy: 0.7565
# Epoch 2/5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.2859 - accuracy: 0.8861
# Epoch 3/5
# 196/196 [==============================] - 13s 68ms/step - loss: 0.2260 - accuracy: 0.9138
# Epoch 4/5
# 196/196 [==============================] - 12s 61ms/step - loss: 0.2105 - accuracy: 0.9192
# Epoch 5/5
# 196/196 [==============================] - 12s 59ms/step - loss: 0.2058 - accuracy: 0.9181
# 196/196 [==============================] - 3s 14ms/step - loss: 0.3550 - accuracy: 0.8735
# accuracy: 0.873520016670227
# loss: 0.3549703061580658

# %%
train_acc2 = hist.history['accuracy']
xc2=range(len(train_acc2))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc2, train_acc2)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %% [markdown]
# #GRU

# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,GRU,Dense
from tensorflow.keras.preprocessing import sequence
max_words = 5000
(xt,yt),(xte,yte)= imdb.load_data(num_words=max_words)

max_len =500
xt=sequence.pad_sequences(xt,maxlen=max_len)
xte=sequence.pad_sequences(xte,maxlen=max_len)

model=Sequential()
model.add(Embedding(max_words,100,input_length=max_len))
model.add(GRU(128))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
batch_size=128
epochs=5
history=model.fit(xt,yt,batch_size=batch_size,epochs=epochs)
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# Epoch 1/5
# 196/196 [==============================] - 36s 173ms/step - loss: 0.5049 - accuracy: 0.7398
# Epoch 2/5
# 196/196 [==============================] - 22s 109ms/step - loss: 0.3011 - accuracy: 0.8770
# Epoch 3/5
# 196/196 [==============================] - 15s 76ms/step - loss: 0.2438 - accuracy: 0.9031
# Epoch 4/5
# 196/196 [==============================] - 11s 54ms/step - loss: 0.2101 - accuracy: 0.9188
# Epoch 5/5
# 196/196 [==============================] - 11s 57ms/step - loss: 0.1731 - accuracy: 0.9351
# 196/196 [==============================] - 3s 12ms/step - loss: 0.3145 - accuracy: 0.8839
# accuracy: 0.8838800191879272
# loss: 0.3145138621330261

# %%
train_acc1 = history.history['accuracy']
xc1=range(len(train_acc1))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc1, train_acc1)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %% [markdown]
# #RNN

# %%
from tensorflow.keras.layers import Embedding,RNN
from keras import layers
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(layers.LSTM(128))
model.add(layers.Dense(10))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
epochs = 4
batch_size = 128

h=model.fit(xt, yt, epochs=epochs, batch_size=batch_size, validation_split=0.2)
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# Epoch 1/4
# 157/157 [==============================] - 32s 184ms/step - loss: 0.5071 - accuracy: 0.7438 - val_loss: 0.3598 - val_accuracy: 0.8420
# Epoch 2/4
# 157/157 [==============================] - 19s 120ms/step - loss: 0.2836 - accuracy: 0.8838 - val_loss: 0.3203 - val_accuracy: 0.8740
# Epoch 3/4
# 157/157 [==============================] - 14s 90ms/step - loss: 0.2327 - accuracy: 0.9089 - val_loss: 0.3122 - val_accuracy: 0.8666
# Epoch 4/4
# 157/157 [==============================] - 11s 70ms/step - loss: 0.1871 - accuracy: 0.9301 - val_loss: 0.3469 - val_accuracy: 0.8564
# 196/196 [==============================] - 3s 14ms/step - loss: 0.3472 - accuracy: 0.8615
# accuracy: 0.8614799976348877
# loss: 0.34722691774368286

# %%
train_loss3 = h.history['loss']
train_acc3 = h.history['accuracy']
xc3=range(len(train_loss3))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %%
plt.plot(xc1, train_acc1)
plt.plot(xc2, train_acc2)
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["GRU","LSTM","RNN"])
