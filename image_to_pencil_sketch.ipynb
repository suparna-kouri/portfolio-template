# %% [markdown]
# <a href="https://colab.research.google.com/github/suparna-kouri/portfolio-template/blob/main/image_to_pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Image to Pencil Sketch in Python**

# %% [markdown]
# This projects is for converting images to the pencil sketch

# %% [markdown]
# We will be using python and its openCV library for the conversion

# %% [markdown]
# **Importing Libraries**

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Reading the Original Image**

# %%
image = cv2.imread("sharuk.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7FA28434F7F0>

# %% [markdown]
# **Convert the RBG image to grayscale**

# %%
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7FA2AB16D370>

# %% [markdown]
# **Invert the grayscale image**

# %%
invert_img = cv2.bitwise_not(gray_img)
cv2_imshow(invert_img)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7FA2842B8280>

# %% [markdown]
# **Apply a Guassian Blur**

# %%
smoothing_img = cv2.GaussianBlur(invert_img, (21,21), sigmaX=0, sigmaY=0)
cv2_imshow(smoothing_img)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7FA2842B81C0>

# %% [markdown]
# **Blend the grayscale image with blurred negative**

# %%
def dodgeV2(x, y):
  return cv2.divide(x, 255-y, scale=256)

# %%
final_img = dodgeV2(gray_img, smoothing_img)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7FA2842B86A0>
